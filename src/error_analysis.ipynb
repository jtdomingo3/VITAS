# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import json
from collections import Counter
import ast
import networkx as nx
import re

# %%
base_path = f"{os.path.dirname(os.getcwd())}\\data"

# %%
error_df = pd.read_excel(f"{base_path}\\output\\error_analysis\\validation_miss.xlsx")

# %%
error_df[["PATHOLOGY", "predicted_diagnosis"]]
# Out:
#                   PATHOLOGY                                predicted_diagnosis
# 0         Viral pharyngitis  {'Cluster headache': 1.0, 'Acute laryngitis': ...
# 1         Viral pharyngitis  {'Acute laryngitis': 1.0, 'Acute otitis media'...
# 2    Chronic rhinosinusitis  {'Viral pharyngitis': 1.0, 'Acute otitis media...
# 3    Chronic rhinosinusitis  {'Viral pharyngitis': 0.9990000000000001, 'Acu...
# 4                      URTI  {'Chronic rhinosinusitis': 0.998, 'Viral phary...
# ..                      ...                                                ...
# 555       Viral pharyngitis  {'Acute otitis media': 1.0, 'Chronic rhinosinu...
# 556              Bronchitis  {'Viral pharyngitis': 1.0, 'Acute otitis media...
# 557                    URTI  {'Acute rhinosinusitis': 0.99, 'Viral pharyngi...
# 558                    URTI  {'Chronic rhinosinusitis': 0.9971428571428572,...
# 559       Viral pharyngitis  {'Acute otitis media': 1.0, 'Chronic rhinosinu...
#
# [560 rows x 2 columns]

# %%
error_df["PATHOLOGY"].value_counts().sort_values().plot.barh()
plt.title("Prediction Miss Frequency")
plt.xlabel("Count")
plt.savefig(f'{base_path}\\output\\error_analysis\\pred_miss_freq.jpg', bbox_inches='tight')
plt.clf()

# %%
with open(f"{base_path}\\input\\release_conditions.json") as f:
  disease_dict = json.load(f)
disease_list = list(disease_dict.keys())

# %%
pred_miss_dict = {}
for disease in disease_list:
    miss_list = []
    for idx, row in error_df[error_df["PATHOLOGY"]==disease].iterrows():
        miss_list.extend(ast.literal_eval(row["predicted_diagnosis"]).keys())
    if miss_list:
        count = dict(Counter(miss_list))
        pred_miss_dict[disease]={i: round(count[i] / len(miss_list), 3) for i in count}
        # pred_miss_dict[disease]=dict(Counter(miss_list))

# %%
pred_miss_dict
# Out:
# {'GERD': {'Acute laryngitis': 0.321,
#   'Acute otitis media': 0.321,
#   'Viral pharyngitis': 0.321,
#   'Cluster headache': 0.012,
#   'Possible NSTEMI / STEMI': 0.012,
#   'Bronchitis': 0.012},
#  'Anemia': {'Stable angina': 0.25,
#   'Possible NSTEMI / STEMI': 0.25,
#   'SLE': 0.292,
#   'Pericarditis': 0.083,
#   'Myocarditis': 0.083,
#   'Pulmonary embolism': 0.042},
#  'Viral pharyngitis': {'Cluster headache': 0.071,
#   'Acute laryngitis': 0.096,
#   'Possible NSTEMI / STEMI': 0.068,
#   'Acute otitis media': 0.315,
#   'GERD': 0.056,
#   'Acute rhinosinusitis': 0.17,
#   'Chronic rhinosinusitis': 0.151,
#   'Bronchitis': 0.052,
#   'URTI': 0.019,
#   'Stable angina': 0.003},
#  'Acute laryngitis': {'Acute otitis media': 0.333,
#   'Bronchitis': 0.097,
#   'Viral pharyngitis': 0.333,
#   'GERD': 0.236},
#  'Myocarditis': {'Stable angina': 0.333,
#   'Pericarditis': 0.273,
#   'Possible NSTEMI / STEMI': 0.273,
#   'Unstable angina': 0.03,
#   'Spontaneous pneumothorax': 0.061,
#   'SLE': 0.03},
#  'SLE': {'Myocarditis': 0.067,
#   'Pericarditis': 0.067,
#   'Anemia': 0.2,
#   'Stable angina': 0.267,
#   'Possible NSTEMI / STEMI': 0.267,
#   'Unstable angina': 0.133},
#  'Unstable angina': {'Stable angina': 0.333,
#   'Possible NSTEMI / STEMI': 0.056,
#   'Anemia': 0.028,
#   'Myocarditis': 0.278,
#   'Spontaneous pneumothorax': 0.278,
#   'SLE': 0.028},
#  'Stable angina': {'Possible NSTEMI / STEMI': 0.259,
#   'Pericarditis': 0.222,
#   'Anemia': 0.037,
#   'Myocarditis': 0.148,
#   'Cluster headache': 0.037,
#   'Acute laryngitis': 0.037,
#   'Acute otitis media': 0.037,
#   'SLE': 0.111,
#   'Unstable angina': 0.074,
#   'Spontaneous pneumothorax': 0.037},
#  'Acute otitis media': {'Acute laryngitis': 0.093,
#   'Viral pharyngitis': 0.308,
#   'GERD': 0.059,
#   'Chronic rhinosinusitis': 0.173,
#   'Acute rhinosinusitis': 0.19,
#   'Possible NSTEMI / STEMI': 0.051,
#   'Cluster headache': 0.055,
#   'Bronchitis': 0.021,
#   'URTI': 0.038,
#   'Influenza': 0.004,
#   'Boerhaave': 0.008},
#  'Bronchospasm / acute asthma exacerbation': {'Atrial fibrillation': 0.333,
#   'Acute dystonic reactions': 0.333,
#   'Bronchiectasis': 0.333},
#  'Bronchitis': {'Viral pharyngitis': 0.316,
#   'Acute otitis media': 0.298,
#   'Acute laryngitis': 0.149,
#   'Acute COPD exacerbation / infection': 0.009,
#   'Bronchiolitis': 0.009,
#   'Bronchiectasis': 0.009,
#   'GERD': 0.053,
#   'Chronic rhinosinusitis': 0.035,
#   'Acute rhinosinusitis': 0.096,
#   'URTI': 0.026},
#  'Pulmonary embolism': {'Stable angina': 0.28,
#   'Pericarditis': 0.24,
#   'Possible NSTEMI / STEMI': 0.28,
#   'Myocarditis': 0.04,
#   'Cluster headache': 0.04,
#   'Viral pharyngitis': 0.04,
#   'Acute otitis media': 0.04,
#   'Localized edema': 0.04},
#  'URTI': {'Chronic rhinosinusitis': 0.061,
#   'Viral pharyngitis': 0.322,
#   'Acute rhinosinusitis': 0.244,
#   'Acute otitis media': 0.318,
#   'Bronchiolitis': 0.019,
#   'Bronchitis': 0.029,
#   'Croup': 0.006},
#  'Influenza': {'Viral pharyngitis': 0.333,
#   'Acute laryngitis': 0.333,
#   'Acute otitis media': 0.333},
#  'Acute rhinosinusitis': {'Acute otitis media': 0.327,
#   'Chronic rhinosinusitis': 0.199,
#   'Viral pharyngitis': 0.333,
#   'URTI': 0.111,
#   'Bronchitis': 0.029},
#  'Chronic rhinosinusitis': {'Viral pharyngitis': 0.333,
#   'Acute otitis media': 0.333,
#   'Acute rhinosinusitis': 0.292,
#   'Bronchitis': 0.01,
#   'URTI': 0.031},
#  'Pulmonary neoplasm': {'Possible NSTEMI / STEMI': 0.333,
#   'Stable angina': 0.333,
#   'Pericarditis': 0.333},
#  'Possible NSTEMI / STEMI': {'Stable angina': 0.173,
#   'SLE': 0.067,
#   'Unstable angina': 0.027,
#   'Pericarditis': 0.133,
#   'Myocarditis': 0.093,
#   'Anemia': 0.04,
#   'Cluster headache': 0.147,
#   'Acute otitis media': 0.147,
#   'Viral pharyngitis': 0.147,
#   'Pulmonary embolism': 0.013,
#   'Pulmonary neoplasm': 0.013},
#  'Pericarditis': {'Myocarditis': 0.296,
#   'Stable angina': 0.333,
#   'Possible NSTEMI / STEMI': 0.333,
#   'SLE': 0.037}}

# %%
pred_miss_df = pd.DataFrame({"disease": pred_miss_dict.keys()})
for disease in disease_list:
    pred_miss_df[disease]=[pred_miss_dict[i].get(disease, 0) for i in pred_miss_dict.keys()]
pred_miss_df.set_index('disease', inplace=True)

# %%
pred_miss_df
# Out:
#                                           Spontaneous pneumothorax  \
# disease
# GERD                                                         0.000
# Anemia                                                       0.000
# Viral pharyngitis                                            0.000
# Acute laryngitis                                             0.000
# Myocarditis                                                  0.061
# SLE                                                          0.000
# Unstable angina                                              0.278
# Stable angina                                                0.037
# Acute otitis media                                           0.000
# Bronchospasm / acute asthma exacerbation                     0.000
# Bronchitis                                                   0.000
# Pulmonary embolism                                           0.000
# URTI                                                         0.000
# Influenza                                                    0.000
# Acute rhinosinusitis                                         0.000
# Chronic rhinosinusitis                                       0.000
# Pulmonary neoplasm                                           0.000
# Possible NSTEMI / STEMI                                      0.000
# Pericarditis                                                 0.000
#
#                                           Cluster headache  Boerhaave  \
# disease
# GERD                                                 0.012      0.000
# Anemia                                               0.000      0.000
# Viral pharyngitis                                    0.071      0.000
# Acute laryngitis                                     0.000      0.000
# Myocarditis                                          0.000      0.000
# SLE                                                  0.000      0.000
# Unstable angina                                      0.000      0.000
# Stable angina                                        0.037      0.000
# Acute otitis media                                   0.055      0.008
# Bronchospasm / acute asthma exacerbation             0.000      0.000
# Bronchitis                                           0.000      0.000
# Pulmonary embolism                                   0.040      0.000
# URTI                                                 0.000      0.000
# Influenza                                            0.000      0.000
# Acute rhinosinusitis                                 0.000      0.000
# Chronic rhinosinusitis                               0.000      0.000
# Pulmonary neoplasm                                   0.000      0.000
# Possible NSTEMI / STEMI                              0.147      0.000
# Pericarditis                                         0.000      0.000
#
#                                           Spontaneous rib fracture   GERD  \
# disease
# GERD                                                             0  0.000
# Anemia                                                           0  0.000
# Viral pharyngitis                                                0  0.056
# Acute laryngitis                                                 0  0.236
# Myocarditis                                                      0  0.000
# SLE                                                              0  0.000
# Unstable angina                                                  0  0.000
# Stable angina                                                    0  0.000
# Acute otitis media                                               0  0.059
# Bronchospasm / acute asthma exacerbation                         0  0.000
# Bronchitis                                                       0  0.053
# Pulmonary embolism                                               0  0.000
# URTI                                                             0  0.000
# Influenza                                                        0  0.000
# Acute rhinosinusitis                                             0  0.000
# Chronic rhinosinusitis                                           0  0.000
# Pulmonary neoplasm                                               0  0.000
# Possible NSTEMI / STEMI                                          0  0.000
# Pericarditis                                                     0  0.000
#
#                                           HIV (initial infection)  Anemia  \
# disease
# GERD                                                            0   0.000
# Anemia                                                          0   0.000
# Viral pharyngitis                                               0   0.000
# Acute laryngitis                                                0   0.000
# Myocarditis                                                     0   0.000
# SLE                                                             0   0.200
# Unstable angina                                                 0   0.028
# Stable angina                                                   0   0.037
# Acute otitis media                                              0   0.000
# Bronchospasm / acute asthma exacerbation                        0   0.000
# Bronchitis                                                      0   0.000
# Pulmonary embolism                                              0   0.000
# URTI                                                            0   0.000
# Influenza                                                       0   0.000
# Acute rhinosinusitis                                            0   0.000
# Chronic rhinosinusitis                                          0   0.000
# Pulmonary neoplasm                                              0   0.000
# Possible NSTEMI / STEMI                                         0   0.040
# Pericarditis                                                    0   0.000
#
#                                           Viral pharyngitis  Inguinal hernia  \
# disease
# GERD                                                  0.321                0
# Anemia                                                0.000                0
# Viral pharyngitis                                     0.000                0
# Acute laryngitis                                      0.333                0
# Myocarditis                                           0.000                0
# SLE                                                   0.000                0
# Unstable angina                                       0.000                0
# Stable angina                                         0.000                0
# Acute otitis media                                    0.308                0
# Bronchospasm / acute asthma exacerbation              0.000                0
# Bronchitis                                            0.316                0
# Pulmonary embolism                                    0.040                0
# URTI                                                  0.322                0
# Influenza                                             0.333                0
# Acute rhinosinusitis                                  0.333                0
# Chronic rhinosinusitis                                0.333                0
# Pulmonary neoplasm                                    0.000                0
# Possible NSTEMI / STEMI                               0.147                0
# Pericarditis                                          0.000                0
#
#                                           Myasthenia gravis  ...  Pneumonia  \
# disease                                                      ...
# GERD                                                      0  ...          0
# Anemia                                                    0  ...          0
# Viral pharyngitis                                         0  ...          0
# Acute laryngitis                                          0  ...          0
# Myocarditis                                               0  ...          0
# SLE                                                       0  ...          0
# Unstable angina                                           0  ...          0
# Stable angina                                             0  ...          0
# Acute otitis media                                        0  ...          0
# Bronchospasm / acute asthma exacerbation                  0  ...          0
# Bronchitis                                                0  ...          0
# Pulmonary embolism                                        0  ...          0
# URTI                                                      0  ...          0
# Influenza                                                 0  ...          0
# Acute rhinosinusitis                                      0  ...          0
# Chronic rhinosinusitis                                    0  ...          0
# Pulmonary neoplasm                                        0  ...          0
# Possible NSTEMI / STEMI                                   0  ...          0
# Pericarditis                                              0  ...          0
#
#                                           Acute rhinosinusitis  \
# disease
# GERD                                                     0.000
# Anemia                                                   0.000
# Viral pharyngitis                                        0.170
# Acute laryngitis                                         0.000
# Myocarditis                                              0.000
# SLE                                                      0.000
# Unstable angina                                          0.000
# Stable angina                                            0.000
# Acute otitis media                                       0.190
# Bronchospasm / acute asthma exacerbation                 0.000
# Bronchitis                                               0.096
# Pulmonary embolism                                       0.000
# URTI                                                     0.244
# Influenza                                                0.000
# Acute rhinosinusitis                                     0.000
# Chronic rhinosinusitis                                   0.292
# Pulmonary neoplasm                                       0.000
# Possible NSTEMI / STEMI                                  0.000
# Pericarditis                                             0.000
#
#                                           Chronic rhinosinusitis  \
# disease
# GERD                                                       0.000
# Anemia                                                     0.000
# Viral pharyngitis                                          0.151
# Acute laryngitis                                           0.000
# Myocarditis                                                0.000
# SLE                                                        0.000
# Unstable angina                                            0.000
# Stable angina                                              0.000
# Acute otitis media                                         0.173
# Bronchospasm / acute asthma exacerbation                   0.000
# Bronchitis                                                 0.035
# Pulmonary embolism                                         0.000
# URTI                                                       0.061
# Influenza                                                  0.000
# Acute rhinosinusitis                                       0.199
# Chronic rhinosinusitis                                     0.000
# Pulmonary neoplasm                                         0.000
# Possible NSTEMI / STEMI                                    0.000
# Pericarditis                                               0.000
#
#                                           Bronchiolitis  Pulmonary neoplasm  \
# disease
# GERD                                              0.000               0.000
# Anemia                                            0.000               0.000
# Viral pharyngitis                                 0.000               0.000
# Acute laryngitis                                  0.000               0.000
# Myocarditis                                       0.000               0.000
# SLE                                               0.000               0.000
# Unstable angina                                   0.000               0.000
# Stable angina                                     0.000               0.000
# Acute otitis media                                0.000               0.000
# Bronchospasm / acute asthma exacerbation          0.000               0.000
# Bronchitis                                        0.009               0.000
# Pulmonary embolism                                0.000               0.000
# URTI                                              0.019               0.000
# Influenza                                         0.000               0.000
# Acute rhinosinusitis                              0.000               0.000
# Chronic rhinosinusitis                            0.000               0.000
# Pulmonary neoplasm                                0.000               0.000
# Possible NSTEMI / STEMI                           0.000               0.013
# Pericarditis                                      0.000               0.000
#
#                                           Possible NSTEMI / STEMI  \
# disease
# GERD                                                        0.012
# Anemia                                                      0.250
# Viral pharyngitis                                           0.068
# Acute laryngitis                                            0.000
# Myocarditis                                                 0.273
# SLE                                                         0.267
# Unstable angina                                             0.056
# Stable angina                                               0.259
# Acute otitis media                                          0.051
# Bronchospasm / acute asthma exacerbation                    0.000
# Bronchitis                                                  0.000
# Pulmonary embolism                                          0.280
# URTI                                                        0.000
# Influenza                                                   0.000
# Acute rhinosinusitis                                        0.000
# Chronic rhinosinusitis                                      0.000
# Pulmonary neoplasm                                          0.333
# Possible NSTEMI / STEMI                                     0.000
# Pericarditis                                                0.333
#
#                                           Sarcoidosis  Pancreatic neoplasm  \
# disease
# GERD                                                0                    0
# Anemia                                              0                    0
# Viral pharyngitis                                   0                    0
# Acute laryngitis                                    0                    0
# Myocarditis                                         0                    0
# SLE                                                 0                    0
# Unstable angina                                     0                    0
# Stable angina                                       0                    0
# Acute otitis media                                  0                    0
# Bronchospasm / acute asthma exacerbation            0                    0
# Bronchitis                                          0                    0
# Pulmonary embolism                                  0                    0
# URTI                                                0                    0
# Influenza                                           0                    0
# Acute rhinosinusitis                                0                    0
# Chronic rhinosinusitis                              0                    0
# Pulmonary neoplasm                                  0                    0
# Possible NSTEMI / STEMI                             0                    0
# Pericarditis                                        0                    0
#
#                                           Acute pulmonary edema  Pericarditis
# disease
# GERD                                                          0         0.000
# Anemia                                                        0         0.083
# Viral pharyngitis                                             0         0.000
# Acute laryngitis                                              0         0.000
# Myocarditis                                                   0         0.273
# SLE                                                           0         0.067
# Unstable angina                                               0         0.000
# Stable angina                                                 0         0.222
# Acute otitis media                                            0         0.000
# Bronchospasm / acute asthma exacerbation                      0         0.000
# Bronchitis                                                    0         0.000
# Pulmonary embolism                                            0         0.240
# URTI                                                          0         0.000
# Influenza                                                     0         0.000
# Acute rhinosinusitis                                          0         0.000
# Chronic rhinosinusitis                                        0         0.000
# Pulmonary neoplasm                                            0         0.333
# Possible NSTEMI / STEMI                                       0         0.133
# Pericarditis                                                  0         0.000
#
# [19 rows x 49 columns]

# %%
pred_miss_graph = pred_miss_df.stack()
pred_miss_graph = pred_miss_graph.rename_axis(('Actual', 'Prediction Miss')).reset_index(name='weight')
pred_miss_graph = pred_miss_graph[pred_miss_graph["weight"]>0]
pred_miss_graph
# Out:
#                       Actual          Prediction Miss  weight
# 1                       GERD         Cluster headache   0.012
# 7                       GERD        Viral pharyngitis   0.321
# 14                      GERD         Acute laryngitis   0.321
# 31                      GERD       Acute otitis media   0.321
# 34                      GERD               Bronchitis   0.012
# ..                       ...                      ...     ...
# 881  Possible NSTEMI / STEMI             Pericarditis   0.133
# 904             Pericarditis              Myocarditis   0.296
# 908             Pericarditis                      SLE   0.037
# 911             Pericarditis            Stable angina   0.333
# 926             Pericarditis  Possible NSTEMI / STEMI   0.333
#
# [124 rows x 3 columns]

# %%
pred_miss_graph.to_csv(f"{base_path}\\output\\error_analysis\\pred_miss_weigths.csv", index=False)

# %%
G = nx.from_pandas_edgelist(pred_miss_graph, 'Actual', 'Prediction Miss', edge_attr='weight', create_using=nx.DiGraph())
pos = nx.spring_layout(G, seed=0)
print(nx.info(G))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 29
# Number of edges: 124
# Average in degree:   4.2759
# Average out degree:   4.2759

# %%
fig = plt.figure(figsize=(15, 8))
weights = [G[u][v]['weight'] for u,v in G.edges()]
nx.draw(G, pos, edge_color=weights, edge_cmap=plt.cm.Blues, with_labels=True)
plt.title("Prediction Miss", fontsize=20)
plt.tight_layout()
plt.savefig(f'{base_path}\\output\\error_analysis\\pred_miss_network.jpg', bbox_inches='tight')
plt.clf()
# Out:
# c:\Users\myras\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:5: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   """

# %%
for disease in pred_miss_dict:
    G = nx.from_pandas_edgelist(pred_miss_graph[pred_miss_graph["Actual"]==disease], 'Actual', 'Prediction Miss', edge_attr='weight', create_using=nx.DiGraph())
    pos = nx.spring_layout(G, seed=0)
    fig = plt.figure(figsize=(15, 8))
    weights = [G[u][v]['weight'] for u,v in G.edges()]
    nx.draw(G, pos, edge_color=weights, edge_cmap=plt.cm.Blues, with_labels=True)
    plt.title(f"Prediction Miss - {disease}", fontsize=20)
    plt.tight_layout()
    img_filename = re.sub('[^a-zA-Z0-9 \n\.]', '', disease).replace(" ", "_")
    plt.savefig(f'{base_path}\\output\\error_analysis\\pred_miss_{img_filename}.jpg', bbox_inches='tight')
    plt.clf()
# Out:
# c:\Users\myras\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:8: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
